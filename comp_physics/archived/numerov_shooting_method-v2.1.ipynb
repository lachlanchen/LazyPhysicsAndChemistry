# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from tqdm import tqdm

# %%
def f(current, E=-0.5):
    return -2*(1/current+E)

# %%
def w_aux(current, h, E=-0.5):
    return 1 - h**2*f(current+h, E)/12

# %%
def dx_aux(current, h, E=-0.5):
    return 1 - h**2*f(current+h, E)/6

# %%
def xh_aux(current, h, E=-0.5):
    return 2+5*h**2*f(current, E=-0.5)/6

# %%
def numerator(current, h, x_current, dx_current, E=-0.5):
    return xh_aux(current, h, E=-0.5) * w_aux(current, -h, E=-0.5) * x_current + 2*h*dx_current*dx_aux(current, -h, E=-0.5)

# %%
def denominator(current, h, x_current, dx_current, E=-0.5):
    return w_aux(current, h, E=-0.5) * dx_aux(current, -h, E=-0.5) + w_aux(current, -h, E=-0.5) * dx_aux(current, h, E=-0.5)

# %%
def xh(current, h, x_current, dx_current, E=-0.5):
    return numerator(current, h, x_current, dx_current, E=-0.5) / denominator(current, h, x_current, dx_current, E=-0.5)

# %%
xh(0.0002, 0.0001, 0, 0.001, E=-0.5)
# Out:
# 1.0000000006481637e-07

# %% [markdown]
# # forward

# %%
E = -0.5

current = 0.00002
h = 0.00001
x_current = 0
dx_current = 0.001

# x_prev = xh(current, -h, x_current, dx_current)




r_values = []
xh_values = []

for i in tqdm(range(500000)):
    
    x_next = xh(current, h, x_current, dx_current, E=-0.5)
    
    x_next_leap_frog = xh(current, 0.75*h, x_current, dx_current, E=-0.5)
    
    dx_current = (x_next - x_next_leap_frog)/(0.25*h)
    
    x_current = x_next
    current = current + h
    
    r_values.append(current)
    xh_values.append(x_current)
# Out:
# 100%|███████████████████████████████| 500000/500000 [00:02<00:00, 211509.20it/s]

# %%
plt.plot(r_values, xh_values)

# %%
r_values = np.array(r_values)

# %%
plt.plot(r_values)

# %%
exact = r_values * np.exp(-r_values)

# %%
plt.plot(r_values, exact)

# %%
r_values
# Out:
# array([3.00000e-05, 4.00000e-05, 5.00000e-05, ..., 5.00000e+00,
#        5.00001e+00, 5.00002e+00])

# %% [markdown]
# # backward

# %%
E = -0.1
current = 10
h = 0.00001
x_current = 0
dx_current = 0.0007

# x_prev = xh(current, -h, x_current, dx_current)




r_values = []
xh_values = []

for i in tqdm(range(int(current / h))):
    
    x_next = xh(current, -h, x_current, dx_current, E=-0.5)
    
    x_next_leap_frog = xh(current, -0.75*h, x_current, dx_current, E=-0.5)
    
    dx_current = (x_next - x_next_leap_frog)/(-0.25*h)
    
    x_current = x_next
    current = current - h
    
    r_values.append(current)
    xh_values.append(-x_current)
# Out:
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 211559.33it/s]

# %%
r_values[-1]
# Out:
# 1.0000209408935746e-05

# %%
plt.plot(r_values[::-1], xh_values[::-1])

# %%
xh_values
# Out:
# [7.000000000046668e-09,
#  1.400000000052792e-08,
#  2.1000000002015425e-08,
#  2.800000000508086e-08,
#  3.500000001029589e-08,
#  4.2000000018232204e-08,
#  4.900000002946144e-08,
#  5.60000000445553e-08,
#  6.300000006408546e-08,
#  7.000000008862355e-08,
#  7.700000011874129e-08,
#  8.400000015501031e-08,
#  9.100000019800227e-08,
#  9.800000024828883e-08,
#  1.050000003064416e-07,
#  1.1200000037303234e-07,
#  1.1900000044863267e-07,
#  1.2600000053381426e-07,
#  1.330000006291488e-07,
#  1.4000000073520785e-07,
#  1.4700000085256307e-07,
#  1.540000009817861e-07,
#  1.6100000112344857e-07,
#  1.6800000127812226e-07,
#  1.750000014463789e-07,
#  1.8200000162879e-07,
#  1.8900000182592734e-07,
#  1.9600000203836253e-07,
#  2.0300000226666724e-07,
#  2.100000025114132e-07,
#  2.1700000277317216e-07,
#  2.2400000305251576e-07,
#  2.3100000335001561e-07,
#  2.380000036662433e-07,
#  2.450000040017704e-07,
#  2.5200000435716843e-07,
#  2.590000047330093e-07,
#  2.6600000512986454e-07,
#  2.730000055483061e-07,
#  2.800000059889054e-07,
#  2.870000064522342e-07,
#  2.940000069388638e-07,
#  3.0100000744936605e-07,
#  3.0800000798431256e-07,
#  3.1500000854427503e-07,
#  3.2200000912982504e-07,
#  3.290000097415343e-07,
#  3.3600001037997435e-07,
#  3.4300001104571694e-07,
#  3.5000001173933406e-07,
#  3.570000124613974e-07,
#  3.640000132124785e-07,
#  3.7100001399314896e-07,
#  3.7800001480398067e-07,
#  3.8500001564554495e-07,
#  3.920000165184136e-07,
#  3.9900001742315836e-07,
#  4.0600001836035076e-07,
#  4.130000193305625e-07,
#  4.2000002033436543e-07,
#  4.27000021372331e-07,
#  4.340000224450305e-07,
#  4.410000235530357e-07,
#  4.4800002469691803e-07,
#  4.5500002587724933e-07,
#  4.620000270946012e-07,
#  4.690000283495454e-07,
#  4.760000296426533e-07,
#  4.830000309744967e-07,
#  4.900000323456471e-07,
#  4.970000337566764e-07,
#  5.040000352081559e-07,
#  5.110000367006574e-07,
#  5.180000382347529e-07,
#  5.250000398110139e-07,
#  5.320000414300116e-07,
#  5.390000430923179e-07,
#  5.460000447985048e-07,
#  5.530000465491437e-07,
#  5.600000483448064e-07,
#  5.670000501860641e-07,
#  5.740000520734891e-07,
#  5.81000054007653e-07,
#  5.880000559891268e-07,
#  5.950000580184822e-07,
#  6.020000600962909e-07,
#  6.090000622231248e-07,
#  6.160000643995552e-07,
#  6.230000666261542e-07,
#  6.300000689034936e-07,
#  6.370000712321446e-07,
#  6.440000736126794e-07,
#  6.510000760456695e-07,
#  6.580000785316863e-07,
#  6.65000081071301e-07,
#  6.720000836650852e-07,
#  6.790000863136112e-07,
#  6.860000890174507e-07,
#  6.93000091777175e-07,
#  7.000000945933562e-07,
#  7.070000974665659e-07,
#  7.140001003973756e-07,
#  7.21000103386357e-07,
#  7.280001064340822e-07,
#  7.350001095411226e-07,
#  7.4200011270805e-07,
#  7.490001159354358e-07,
#  7.560001192238517e-07,
#  7.630001225738695e-07,
#  7.70000125986061e-07,
#  7.770001294609973e-07,
#  7.840001329992508e-07,
#  7.910001366013928e-07,
#  7.980001402679949e-07,
#  8.050001439996289e-07,
#  8.120001477968666e-07,
#  8.190001516602793e-07,
#  8.260001555904387e-07,
#  8.330001595879161e-07,
#  8.400001636532833e-07,
#  8.470001677871119e-07,
#  8.540001719899726e-07,
#  8.610001762624371e-07,
#  8.680001806050775e-07,
#  8.750001850184651e-07,
#  8.820001895031715e-07,
#  8.890001940597686e-07,
#  8.960001986888282e-07,
#  9.030002033909217e-07,
#  9.100002081666207e-07,
#  9.170002130164967e-07,
#  9.240002179411218e-07,
#  9.310002229410677e-07,
#  9.380002280169058e-07,
#  9.450002331692073e-07,
#  9.52000238398544e-07,
#  9.590002437054876e-07,
#  9.660002490906087e-07,
#  9.730002545544797e-07,
#  9.800002600976718e-07,
#  9.870002657207565e-07,
#  9.940002714243059e-07,
#  1.0010002772088922e-06,
#  1.0080002830750882e-06,
#  1.0150002890234655e-06,
#  1.0220002950545951e-06,
#  1.0290003011690487e-06,
#  1.0360003073673968e-06,
#  1.04300031365021e-06,
#  1.0500003200180615e-06,
#  1.0570003264715226e-06,
#  1.0640003330111653e-06,
#  1.07100033963756e-06,
#  1.0780003463512793e-06,
#  1.0850003531528948e-06,
#  1.0920003600429786e-06,
#  1.0990003670221022e-06,
#  1.1060003740908373e-06,
#  1.1130003812497548e-06,
#  1.1200003884994265e-06,
#  1.1270003958404242e-06,
#  1.1340004032733203e-06,
#  1.1410004107986858e-06,
#  1.1480004184170916e-06,
#  1.1550004261291094e-06,
#  1.1620004339353105e-06,
#  1.1690004418362678e-06,
#  1.1760004498325515e-06,
#  1.1830004579247334e-06,
#  1.1900004661133854e-06,
#  1.197000474399079e-06,
#  1.2040004827823854e-06,
#  1.2110004912638778e-06,
#  1.2180004998441268e-06,
#  1.225000508523703e-06,
#  1.2320005173031778e-06,
#  1.2390005261831231e-06,
#  1.2460005351641107e-06,
#  1.2530005442467123e-06,
#  1.2600005534315004e-06,
#  1.2670005627190463e-06,
#  1.2740005721099222e-06,
#  1.2810005816046991e-06,
#  1.2880005912039496e-06,
#  1.2950006009082444e-06,
#  1.3020006107181544e-06,
#  1.3090006206342507e-06,
#  1.3160006306571052e-06,
#  1.3230006407872903e-06,
#  1.3300006510253779e-06,
#  1.3370006613719394e-06,
#  1.344000671827547e-06,
#  1.351000682392772e-06,
#  1.3580006930681864e-06,
#  1.3650007038543627e-06,
#  1.372000714751872e-06,
#  1.3790007257612857e-06,
#  1.3860007368831753e-06,
#  1.3930007481181137e-06,
#  1.400000759466672e-06,
#  1.4070007709294216e-06,
#  1.4140007825069327e-06,
#  1.4210007941997771e-06,
#  1.428000806008526e-06,
#  1.4350008179337515e-06,
#  1.442000829976025e-06,
#  1.4490008421359178e-06,
#  1.4560008544140014e-06,
#  1.4630008668108479e-06,
#  1.4700008793270301e-06,
#  1.4770008919631196e-06,
#  1.4840009047196883e-06,
#  1.4910009175973078e-06,
#  1.4980009305965489e-06,
#  1.5050009437179827e-06,
#  1.5120009569621817e-06,
#  1.519000970329717e-06,
#  1.52600098382116e-06,
#  1.533000997437082e-06,
#  1.5400010111780553e-06,
#  1.5470010250446517e-06,
#  1.554001039037443e-06,
#  1.5610010531570002e-06,
#  1.5680010674038948e-06,
#  1.5750010817786979e-06,
#  1.582001096281981e-06,
#  1.5890011109143172e-06,
#  1.5960011256762775e-06,
#  1.6030011405684324e-06,
#  1.6100011555913536e-06,
#  1.6170011707456121e-06,
#  1.6240011860317804e-06,
#  1.6310012014504292e-06,
#  1.6380012170021306e-06,
#  1.6450012326874563e-06,
#  1.6520012485069783e-06,
#  1.6590012644612688e-06,
#  1.6660012805508994e-06,
#  1.673001296776443e-06,
#  1.6800013131384713e-06,
#  1.687001329637555e-06,
#  1.694001346274267e-06,
#  1.701001363049178e-06,
#  1.7080013799628596e-06,
#  1.715001397015884e-06,
#  1.7220014142088227e-06,
#  1.7290014315422475e-06,
#  1.73600144901673e-06,
#  1.7430014666328421e-06,
#  1.750001484391156e-06,
#  1.757001502292242e-06,
#  1.7640015203366712e-06,
#  1.771001538525015e-06,
#  1.7780015568578444e-06,
#  1.7850015753357301e-06,
#  1.7920015939592438e-06,
#  1.7990016127289582e-06,
#  1.8060016316454447e-06,
#  1.8130016507092746e-06,
#  1.8200016699210191e-06,
#  1.8270016892812506e-06,
#  1.8340017087905403e-06,
#  1.8410017284494596e-06,
#  1.8480017482585804e-06,
#  1.8550017682184744e-06,
#  1.8620017883297133e-06,
#  1.8690018085928682e-06,
#  1.8760018290085117e-06,
#  1.8830018495772155e-06,
#  1.8900018702995512e-06,
#  1.8970018911760899e-06,
#  1.9040019122074048e-06,
#  1.9110019333940674e-06,
#  1.9180019547366495e-06,
#  1.9250019762357244e-06,
#  1.9320019978918637e-06,
#  1.9390020197056375e-06,
#  1.946002041677618e-06,
#  1.9530020638083766e-06,
#  1.960002086098485e-06,
#  1.9670021085485127e-06,
#  1.9740021311590307e-06,
#  1.9810021539306104e-06,
#  1.988002176863824e-06,
#  1.9950021999592436e-06,
#  2.0020022232174424e-06,
#  2.009002246638991e-06,
#  2.0160022702244606e-06,
#  2.023002293974422e-06,
#  2.0300023178894497e-06,
#  2.037002341970114e-06,
#  2.0440023662169863e-06,
#  2.0510023906306375e-06,
#  2.0580024152116397e-06,
#  2.0650024399605644e-06,
#  2.072002464877984e-06,
#  2.0790024899644694e-06,
#  2.086002515220593e-06,
#  2.093002540646926e-06,
#  2.100002566244039e-06,
#  2.1070025920125035e-06,
#  2.114002617952891e-06,
#  2.1210026440657716e-06,
#  2.1280026703517177e-06,
#  2.1350026968113e-06,
#  2.142002723445091e-06,
#  2.149002750253662e-06,
#  2.156002777237583e-06,
#  2.1630028043974244e-06,
#  2.1700028317337586e-06,
#  2.1770028592471595e-06,
#  2.184002886938198e-06,
#  2.1910029148074452e-06,
#  2.198002942855472e-06,
#  2.2050029710828508e-06,
#  2.212002999490151e-06,
#  2.2190030280779468e-06,
#  2.226003056846809e-06,
#  2.2330030857973084e-06,
#  2.240003114930016e-06,
#  2.2470031442455034e-06,
#  2.2540031737443424e-06,
#  2.261003203427104e-06,
#  2.2680032332943595e-06,
#  2.275003263346683e-06,
#  2.282003293584645e-06,
#  2.2890033240088166e-06,
#  2.296003354619771e-06,
#  2.30300338541808e-06,
#  2.3100034164043164e-06,
#  2.317003447579051e-06,
#  2.3240034789428555e-06,
#  2.331003510496301e-06,
#  2.3380035422399596e-06,
#  2.3450035741744016e-06,
#  2.3520036063001997e-06,
#  2.3590036386179254e-06,
#  2.3660036711281508e-06,
#  2.373003703831447e-06,
#  2.380003736728386e-06,
#  2.387003769819538e-06,
#  2.394003803105475e-06,
#  2.4010038365867676e-06,
#  2.4080038702639887e-06,
#  2.4150039041377097e-06,
#  2.4220039382085026e-06,
#  2.42900397247694e-06,
#  2.436004006943593e-06,
#  2.4430040416090327e-06,
#  2.450004076473831e-06,
#  2.4570041115385572e-06,
#  2.464004146803783e-06,
#  2.471004182270081e-06,
#  2.4780042179380227e-06,
#  2.4850042538081783e-06,
#  2.49200428988112e-06,
#  2.49900432615742e-06,
#  2.5060043626376517e-06,
#  2.5130043993223857e-06,
#  2.5200044362121945e-06,
#  2.5270044733076484e-06,
#  2.5340045106093172e-06,
#  2.5410045481177718e-06,
#  2.548004585833583e-06,
#  2.555004623757322e-06,
#  2.5620046618895617e-06,
#  2.5690047002308753e-06,
#  2.576004738781833e-06,
#  2.583004777543007e-06,
#  2.5900048165149684e-06,
#  2.5970048556982895e-06,
#  2.604004895093543e-06,
#  2.6110049347013e-06,
#  2.618004974522133e-06,
#  2.6250050145566125e-06,
#  2.6320050548053097e-06,
#  2.6390050952687958e-06,
#  2.646005135947644e-06,
#  2.653005176842425e-06,
#  2.6600052179537105e-06,
#  2.6670052592820736e-06,
#  2.674005300828086e-06,
#  2.6810053425923174e-06,
#  2.6880053845753408e-06,
#  2.695005426777728e-06,
#  2.7020054692000505e-06,
#  2.70900551184288e-06,
#  2.716005554706785e-06,
#  2.723005597792338e-06,
#  2.7300056411001114e-06,
#  2.737005684630678e-06,
#  2.7440057283846084e-06,
#  2.751005772362474e-06,
#  2.758005816564848e-06,
#  2.765005860992301e-06,
#  2.772005905645405e-06,
#  2.7790059505247307e-06,
#  2.7860059956308506e-06,
#  2.7930060409643344e-06,
#  2.8000060865257543e-06,
#  2.8070061323156813e-06,
#  2.8140061783346863e-06,
#  2.821006224583342e-06,
#  2.828006271062223e-06,
#  2.8350063177718993e-06,
#  2.842006364712943e-06,
#  2.8490064118859255e-06,
#  2.8560064592914184e-06,
#  2.8630065069299922e-06,
#  2.8700065548022184e-06,
#  2.877006602908669e-06,
#  2.8840066512499153e-06,
#  2.8910066998265277e-06,
#  2.8980067486390787e-06,
#  2.9050067976881377e-06,
#  2.912006846974278e-06,
#  2.919006896498071e-06,
#  2.9260069462600866e-06,
#  2.933006996260896e-06,
#  2.9400070465010727e-06,
#  2.9470070969811867e-06,
#  2.95400714770181e-06,
#  2.9610071986635145e-06,
#  2.968007249866873e-06,
#  2.975007301312456e-06,
#  2.9820073530008355e-06,
#  2.9890074049325823e-06,
#  2.996007457108271e-06,
#  3.0030075095284743e-06,
#  3.010007562193763e-06,
#  3.0170076151047092e-06,
#  3.0240076682618827e-06,
#  3.031007721665857e-06,
#  3.038007775317202e-06,
#  3.045007829216488e-06,
#  3.052007883364287e-06,
#  3.059007937761171e-06,
#  3.066007992407714e-06,
#  3.0730080473044856e-06,
#  3.080008102452058e-06,
#  3.0870081578510022e-06,
#  3.094008213501887e-06,
#  3.1010082694052823e-06,
#  3.1080083255617605e-06,
#  3.115008381971893e-06,
#  3.122008438636253e-06,
#  3.1290084955554105e-06,
#  3.1360085527299398e-06,
#  3.143008610160413e-06,
#  3.1500086678474015e-06,
#  3.1570087257914763e-06,
#  3.1640087839932096e-06,
#  3.171008842453172e-06,
#  3.178008901171933e-06,
#  3.1850089601500658e-06,
#  3.1920090193881405e-06,
#  3.19900907888673e-06,
#  3.2060091386464054e-06,
#  3.2130091986677386e-06,
#  3.2200092589512997e-06,
#  3.227009319497661e-06,
#  3.234009380307395e-06,
#  3.2410094413810744e-06,
#  3.24800950271927e-06,
#  3.255009564322553e-06,
#  3.262009626191495e-06,
#  3.269009688326667e-06,
#  3.276009750728639e-06,
#  3.283009813397982e-06,
#  3.290009876335268e-06,
#  3.2970099395410682e-06,
#  3.3040100030159535e-06,
#  3.311010066760495e-06,
#  3.3180101307752646e-06,
#  3.325010195060834e-06,
#  3.332010259617779e-06,
#  3.33901032444667e-06,
#  3.3460103895480783e-06,
#  3.3530104549225768e-06,
#  3.360010520570738e-06,
#  3.367010586493134e-06,
#  3.3740106526903343e-06,
#  3.381010719162911e-06,
#  3.3880107859114338e-06,
#  3.3950108529364734e-06,
#  3.402010920238601e-06,
#  3.409010987818389e-06,
#  3.4160110556764083e-06,
#  3.4230111238132333e-06,
#  3.430011192229435e-06,
#  3.4370112609255856e-06,
#  3.4440113299022547e-06,
#  3.451011399160015e-06,
#  3.458011468699438e-06,
#  3.465011538521092e-06,
#  3.472011608625548e-06,
#  3.479011679013377e-06,
#  3.4860117496851526e-06,
#  3.493011820641445e-06,
#  3.5000118918828277e-06,
#  3.5070119634098724e-06,
#  3.514012035223151e-06,
#  3.521012107323235e-06,
#  3.528012179710698e-06,
#  3.53501225238611e-06,
#  3.5420123253500426e-06,
#  3.5490123986030677e-06,
#  3.556012472145759e-06,
#  3.5630125459786874e-06,
#  3.5700126201024242e-06,
#  3.5770126945175413e-06,
#  3.5840127692246085e-06,
#  3.591012844224198e-06,
#  3.598012919516883e-06,
#  3.6050129951032334e-06,
#  3.612013070983821e-06,
#  3.6190131471592176e-06,
#  3.6260132236299946e-06,
#  3.633013300396723e-06,
#  3.6400133774599728e-06,
#  3.647013454820314e-06,
#  3.6540135324783174e-06,
#  3.6610136104345573e-06,
#  3.668013688689605e-06,
#  3.6750137672440328e-06,
#  3.6820138460984114e-06,
#  3.6890139252533155e-06,
#  3.696014004709317e-06,
#  3.703014084466986e-06,
#  3.7100141645268945e-06,
#  3.717014244889614e-06,
#  3.724014325555716e-06,
#  3.7310144065257706e-06,
#  3.73801448780035e-06,
#  3.7450145693800255e-06,
#  3.7520146512653675e-06,
#  3.7590147334569475e-06,
#  3.766014815955337e-06,
#  3.7730148987611067e-06,
#  3.78001498187483e-06,
#  3.787015065297078e-06,
#  3.794015149028423e-06,
#  3.8010152330694345e-06,
#  3.808015317420685e-06,
#  3.815015402082747e-06,
#  3.822015487056192e-06,
#  3.829015572341591e-06,
#  3.836015657939509e-06,
#  3.84301574385052e-06,
#  3.8500158300751975e-06,
#  3.857015916614113e-06,
#  3.864016003467837e-06,
#  3.8710160906369396e-06,
#  3.8780161781219905e-06,
#  3.8850162659235625e-06,
#  3.892016354042228e-06,
#  3.899016442478559e-06,
#  3.906016531233124e-06,
#  3.913016620306495e-06,
#  3.920016709699245e-06,
#  3.927016799411945e-06,
#  3.934016889445163e-06,
#  3.941016979799473e-06,
#  3.948017070475449e-06,
#  3.955017161473663e-06,
#  3.9620172527946844e-06,
#  3.969017344439084e-06,
#  3.976017436407432e-06,
#  3.983017528700306e-06,
#  3.99001762131828e-06,
#  3.997017714261922e-06,
#  4.004017807531805e-06,
#  4.011017901128502e-06,
#  4.018017995052582e-06,
#  4.025018089304613e-06,
#  4.032018183885166e-06,
#  4.039018278794813e-06,
#  4.046018374034126e-06,
#  4.053018469603674e-06,
#  4.060018565504029e-06,
#  4.067018661735764e-06,
#  4.07401875829945e-06,
#  4.081018855195661e-06,
#  4.088018952424968e-06,
#  4.0950190499879425e-06,
#  4.1020191478851545e-06,
#  4.109019246117179e-06,
#  4.116019344684586e-06,
#  4.123019443587948e-06,
#  4.130019542827834e-06,
#  4.137019642404818e-06,
#  4.14401974231947e-06,
#  4.151019842572361e-06,
#  4.158019943164063e-06,
#  4.165020044095149e-06,
#  4.172020145366187e-06,
#  4.179020246977749e-06,
#  4.186020348930408e-06,
#  4.193020451224734e-06,
#  4.200020553861296e-06,
#  4.207020656840664e-06,
#  4.21402076016341e-06,
#  4.221020863830104e-06,
#  4.2280209678413175e-06,
#  4.235021072197624e-06,
#  4.242021176899596e-06,
#  4.2490212819478094e-06,
#  4.2560213873428325e-06,
#  4.2630214930852365e-06,
#  4.270021599175596e-06,
#  4.277021705614479e-06,
#  4.2840218124024574e-06,
#  4.291021919540103e-06,
#  4.2980220270279865e-06,
#  4.305022134866679e-06,
#  4.312022243056753e-06,
#  4.319022351598777e-06,
#  4.326022460493327e-06,
#  4.3330225697409724e-06,
#  4.340022679342287e-06,
#  4.347022789297844e-06,
#  4.354022899608215e-06,
#  4.361023010273969e-06,
#  4.368023121295685e-06,
#  4.375023232673931e-06,
#  4.382023344409278e-06,
#  4.389023456502301e-06,
#  4.396023568953565e-06,
#  4.403023681763641e-06,
#  4.410023794933101e-06,
#  4.4170239084625165e-06,
#  4.4240240223524585e-06,
#  4.431024136603498e-06,
#  4.438024251216206e-06,
#  4.445024366191154e-06,
#  4.4520244815289146e-06,
#  4.45902459723006e-06,
#  4.466024713295161e-06,
#  4.473024829724791e-06,
#  4.480024946519522e-06,
#  4.487025063679925e-06,
#  4.4940251812065755e-06,
#  4.501025299100044e-06,
#  4.508025417360903e-06,
#  4.515025535989724e-06,
#  4.522025654987077e-06,
#  4.5290257743535345e-06,
#  4.536025894089666e-06,
#  4.5430260141960425e-06,
#  4.550026134673235e-06,
#  4.557026255521815e-06,
#  4.564026376742356e-06,
#  4.57102649833543e-06,
#  4.578026620301606e-06,
#  4.585026742641453e-06,
#  4.592026865355541e-06,
#  4.599026988444445e-06,
#  4.606027111908737e-06,
#  4.61302723574899e-06,
#  4.620027359965774e-06,
#  4.6270274845596585e-06,
#  4.634027609531216e-06,
#  4.6410277348810194e-06,
#  4.648027860609638e-06,
#  4.655027986717646e-06,
#  4.662028113205615e-06,
#  4.669028240074117e-06,
#  4.676028367323723e-06,
#  4.6830284949550035e-06,
#  4.690028622968532e-06,
#  4.697028751364883e-06,
#  4.704028880144626e-06,
#  4.711029009308331e-06,
#  4.718029138856573e-06,
#  4.725029268789925e-06,
#  4.732029399108956e-06,
#  4.739029529814239e-06,
#  4.746029660906346e-06,
#  4.753029792385847e-06,
#  4.760029924253313e-06,
#  4.767030056509311e-06,
#  4.774030189154414e-06,
#  4.781030322189193e-06,
#  4.788030455614222e-06,
#  4.7950305894300705e-06,
#  4.80203072363731e-06,
#  4.809030858236509e-06,
#  4.816030993228243e-06,
#  4.823031128613086e-06,
#  4.830031264391607e-06,
#  4.837031400564377e-06,
#  4.84403153713197e-06,
#  4.851031674094956e-06,
#  4.858031811453904e-06,
#  4.865031949209387e-06,
#  4.872032087361977e-06,
#  4.879032225912244e-06,
#  4.8860323648607595e-06,
#  4.893032504208093e-06,
#  4.900032643954814e-06,
#  4.907032784101495e-06,
#  4.9140329246487056e-06,
#  4.9210330655970184e-06,
#  4.928033206947005e-06,
#  4.935033348699239e-06,
#  4.94203349085429e-06,
#  4.949033633412735e-06,
#  4.956033776375142e-06,
#  4.963033919742079e-06,
#  4.9700340635141205e-06,
#  4.977034207691837e-06,
#  4.9840343522758025e-06,
#  4.9910344972665895e-06,
#  4.99803464266477e-06,
#  5.005034788470913e-06,
#  5.012034934685591e-06,
#  5.019035081309378e-06,
#  5.026035228342845e-06,
#  5.033035375786562e-06,
#  5.0400355236410975e-06,
#  5.047035671907025e-06,
#  5.054035820584917e-06,
#  5.061035969675342e-06,
#  5.06803611917887e-06,
#  5.075036269096077e-06,
#  5.082036419427531e-06,
#  5.089036570173803e-06,
#  5.0960367213354645e-06,
#  5.103036872913088e-06,
#  5.110037024907243e-06,
#  5.117037177318506e-06,
#  5.124037330147449e-06,
#  5.13103748339464e-06,
#  5.138037637060649e-06,
#  5.14503779114605e-06,
#  5.152037945651414e-06,
#  5.159038100577311e-06,
#  5.166038255924313e-06,
#  5.173038411692991e-06,
#  5.1800385678839155e-06,
#  5.187038724497663e-06,
#  5.194038881534803e-06,
#  5.201039038995905e-06,
#  5.208039196881545e-06,
#  5.215039355192291e-06,
#  5.222039513928713e-06,
#  5.229039673091384e-06,
#  5.236039832680876e-06,
#  5.2430399926977585e-06,
#  5.2500401531426005e-06,
#  5.257040314015978e-06,
#  5.26404047531846e-06,
#  5.2710406370506195e-06,
#  5.278040799213026e-06,
#  5.285040961806252e-06,
#  5.292041124830869e-06,
#  5.299041288287447e-06,
#  5.306041452176556e-06,
#  5.313041616498771e-06,
#  5.3200417812546636e-06,
#  5.327041946444807e-06,
#  5.334042112069772e-06,
#  5.3410422781301335e-06,
#  5.34804244462646e-06,
#  5.355042611559323e-06,
#  5.362042778929296e-06,
#  5.3690429467369495e-06,
#  5.376043114982853e-06,
#  5.383043283667583e-06,
#  5.3900434527917096e-06,
#  5.397043622355803e-06,
#  5.404043792360434e-06,
#  5.4110439628061775e-06,
#  5.418044133693602e-06,
#  5.425044305023277e-06,
#  5.432044476795776e-06,
#  5.439044649011671e-06,
#  5.446044821671531e-06,
#  5.4530449947759284e-06,
#  5.460045168325433e-06,
#  5.467045342320618e-06,
#  5.4740455167620535e-06,
#  5.481045691650307e-06,
#  5.488045866985952e-06,
#  5.495046042769563e-06,
#  5.502046219001709e-06,
#  5.50904639568296e-06,
#  5.516046572813885e-06,
#  5.523046750395057e-06,
#  5.530046928427047e-06,
#  5.5370471069104275e-06,
#  5.544047285845772e-06,
#  5.551047465233649e-06,
#  5.55804764507463e-06,
#  5.565047825369287e-06,
#  5.572048006118192e-06,
#  5.579048187321914e-06,
#  5.586048368981026e-06,
#  5.593048551096097e-06,
#  5.600048733667704e-06,
#  5.607048916696418e-06,
#  5.614049100182812e-06,
#  5.62104928412746e-06,
#  5.628049468530933e-06,
#  5.635049653393801e-06,
#  5.642049838716633e-06,
#  5.6490500245000084e-06,
#  5.656050210744496e-06,
#  5.663050397450665e-06,
#  5.670050584619089e-06,
#  5.677050772250343e-06,
#  5.684050960344997e-06,
#  5.691051148903621e-06,
#  5.698051337926784e-06,
#  5.705051527415057e-06,
#  5.71205171736901e-06,
#  5.719051907789215e-06,
#  5.72605209867624e-06,
#  5.733052290030661e-06,
#  5.740052481853047e-06,
#  5.74705267414397e-06,
#  5.7540528669040014e-06,
#  5.761053060133714e-06,
#  5.768053253833676e-06,
#  5.7750534480044585e-06,
#  5.782053642646636e-06,
#  5.789053837760778e-06,
#  5.796054033347458e-06,
#  5.803054229407248e-06,
#  5.81005442594072e-06,
#  5.817054622948444e-06,
#  5.824054820430991e-06,
#  5.831055018388932e-06,
#  5.838055216822836e-06,
#  5.845055415733275e-06,
#  5.852055615120818e-06,
#  5.859055814986039e-06,
#  5.866056015329509e-06,
#  5.873056216151798e-06,
#  5.880056417453474e-06,
#  5.88705661923511e-06,
#  5.894056821497277e-06,
#  5.901057024240546e-06,
#  5.90805722746549e-06,
#  5.915057431172682e-06,
#  5.922057635362694e-06,
#  5.929057840036095e-06,
#  5.9360580451934555e-06,
#  5.9430582508353505e-06,
#  5.95005845696235e-06,
#  5.957058663575025e-06,
#  5.9640588706739455e-06,
#  5.971059078259681e-06,
#  5.9780592863328106e-06,
#  5.985059494893904e-06,
#  5.9920597039435335e-06,
#  5.999059913482271e-06,
#  6.006060123510687e-06,
#  6.01306033402935e-06,
#  6.020060545038836e-06,
#  6.027060756539717e-06,
#  6.034060968532564e-06,
#  6.041061181017948e-06,
#  6.048061393996442e-06,
#  6.055061607468615e-06,
#  6.062061821435038e-06,
#  6.0690620358962766e-06,
#  6.076062250852912e-06,
#  6.083062466305512e-06,
#  6.090062682254649e-06,
#  6.097062898700894e-06,
#  6.104063115644819e-06,
#  6.111063333086994e-06,
#  6.118063551027991e-06,
#  6.125063769468381e-06,
#  6.132063988408734e-06,
#  6.1390642078496245e-06,
#  6.14606442779162e-06,
#  6.153064648235292e-06,
#  6.160064869181215e-06,
#  6.167065090629958e-06,
#  6.174065312582091e-06,
#  6.181065535038185e-06,
#  6.188065757998814e-06,
#  6.195065981464547e-06,
#  6.202066205435957e-06,
#  6.209066429913616e-06,
#  6.216066654898094e-06,
#  6.223066880389965e-06,
#  6.230067106389801e-06,
#  6.237067332898173e-06,
#  6.2440675599156534e-06,
#  6.2510677874428105e-06,
#  6.258068015480215e-06,
#  6.265068244028439e-06,
#  6.272068473088052e-06,
#  6.279068702659627e-06,
#  6.286068932743732e-06,
#  6.293069163340942e-06,
#  6.30006939445183e-06,
#  6.3070696260769714e-06,
#  6.31406985821694e-06,
#  6.321070090872307e-06,
#  6.3280703240436425e-06,
#  6.3350705577315175e-06,
#  6.342070791936508e-06,
#  6.349071026659185e-06,
#  6.356071261900119e-06,
#  6.36307149765988e-06,
#  6.370071733939042e-06,
#  6.377071970738175e-06,
#  6.3840722080578485e-06,
#  6.3910724458986355e-06,
#  6.3980726842611074e-06,
#  6.405072923145837e-06,
#  6.412073162553394e-06,
#  6.419073402484351e-06,
#  6.4260736429392775e-06,
#  6.433073883918745e-06,
#  6.440074125423326e-06,
#  6.447074367453591e-06,
#  6.454074610010111e-06,
#  6.4610748530934565e-06,
#  6.4680750967042006e-06,
#  6.475075340842915e-06,
#  6.482075585510169e-06,
#  6.489075830706535e-06,
#  6.496076076432583e-06,
#  6.503076322688885e-06,
#  6.510076569476014e-06,
#  6.517076816794538e-06,
#  6.524077064645028e-06,
#  6.531077313028059e-06,
#  6.5380775619442e-06,
#  6.5450778113940206e-06,
#  6.552078061378094e-06,
#  6.559078311896991e-06,
#  6.566078562951286e-06,
#  6.573078814541551e-06,
#  6.580079066668358e-06,
#  6.587079319332281e-06,
#  6.594079572533891e-06,
#  6.601079826273757e-06,
#  6.608080080552451e-06,
#  6.615080335370546e-06,
#  6.622080590728612e-06,
#  6.6290808466272135e-06,
#  6.636081103066922e-06,
#  6.6430813600483166e-06,
#  6.650081617571969e-06,
#  6.6570818756384475e-06,
#  6.6640821342483205e-06,
#  6.671082393402162e-06,
#  6.678082653100542e-06,
#  6.68508291334403e-06,
#  6.6920831741331985e-06,
#  6.699083435468619e-06,
#  6.706083697350866e-06,
#  6.7130839597805105e-06,
#  6.720084222758122e-06,
#  6.727084486284278e-06,
#  6.734084750359549e-06,
#  6.7410850149845045e-06,
#  6.7480852801597155e-06,
#  6.755085545885755e-06,
#  6.762085812163191e-06,
#  6.769086078992593e-06,
#  6.7760863463745356e-06,
#  6.783086614309588e-06,
#  6.790086882798321e-06,
#  6.7970871518413055e-06,
#  6.804087421439112e-06,
#  6.811087691592314e-06,
#  6.8180879623014795e-06,
#  6.825088233567177e-06,
#  6.832088505389977e-06,
#  6.8390887777704575e-06,
#  6.846089050709188e-06,
#  6.853089324206738e-06,
#  6.860089598263681e-06,
#  6.867089872880588e-06,
#  6.874090148058029e-06,
#  6.881090423796576e-06,
#  6.888090700096801e-06,
#  6.8950909769592755e-06,
#  6.90209125438457e-06,
#  6.909091532373255e-06,
#  6.916091810925903e-06,
#  6.923092090043089e-06,
#  6.930092369725383e-06,
#  6.937092649973354e-06,
#  6.9440929307875786e-06,
#  6.9510932121686245e-06,
#  6.958093494117062e-06,
#  6.9650937766334645e-06,
#  6.97209405971841e-06,
#  6.979094343372468e-06,
#  6.98609462759621e-06,
#  6.993094912390207e-06,
#  7.000095197755027e-06,
#  ...]

# %%
r_values = np.array(r_values)
exact = r_values * np.exp(-r_values)

plt.plot(r_values, exact)
plt.plot(r_values[::-1], xh_values[::-1])

# %% [markdown]
# # Shooting Method

# %%
def numerov(E, h, current, x_current=0, dx_current=0.007, direction=-1):
    # E = -0.1
    # current = 10
    # h = 0.00001
    # x_current = 0
    # dx_current = 0.0007

    # x_prev = xh(current, -h, x_current, dx_current)

    
    if direction not in [-1, 1]:
        raise Exception("Invalid direction")

    n_steps = int(current / h)

    r_values = np.zeros((n_steps, ), dtype=float)
    xh_values = np.zeros((n_steps, ), dtype=float)

    
    for i in tqdm(range(n_steps), position=0, leave=True):

        x_next = xh(current, h*direction, x_current, dx_current, E=E)

        x_next_leap_frog = xh(current, 0.75*h*direction, x_current, dx_current, E=E)

        dx_current = (x_next - x_next_leap_frog)/(0.25*h*direction)

        x_current = x_next
        current = current + h * direction

        r_values[::direction][i] = current
        xh_values[::direction][i] = x_current
        
    normalization_factor = np.sqrt((xh_values * xh_values).sum())
    
    xh_values /= normalization_factor
        
    return r_values, xh_values * direction, xh_values[0], xh_values[-1]

# %%
E = -0.5
current = 10
h = 0.00001
x_current = 0
dx_current = 0.0007

r_values, xh_values, u0, un = numerov(E, h, current, x_current=x_current, dx_current=dx_current, direction=-1)
# Out:
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 202329.64it/s]

# %%
plt.plot(r_values, xh_values)

# %%
exact = r_values * np.exp(-r_values)
exact /= np.sqrt((exact*exact).sum())
plt.plot(r_values, exact)
plt.legend("exact")
plt.plot(r_values, xh_values)
plt.legend("approx")

# %%
E_guess = np.linspace(-0.7, 0.7, int(4/0.1))

# %%
E_guess
# Out:
# array([-0.7       , -0.66410256, -0.62820513, -0.59230769, -0.55641026,
#        -0.52051282, -0.48461538, -0.44871795, -0.41282051, -0.37692308,
#        -0.34102564, -0.30512821, -0.26923077, -0.23333333, -0.1974359 ,
#        -0.16153846, -0.12564103, -0.08974359, -0.05384615, -0.01794872,
#         0.01794872,  0.05384615,  0.08974359,  0.12564103,  0.16153846,
#         0.1974359 ,  0.23333333,  0.26923077,  0.30512821,  0.34102564,
#         0.37692308,  0.41282051,  0.44871795,  0.48461538,  0.52051282,
#         0.55641026,  0.59230769,  0.62820513,  0.66410256,  0.7       ])

# %%
_, _, u0_last, _ = numerov(-4, h, current, x_current=x_current, dx_current=dx_current, direction=-1)
for egs in tqdm(E_guess, position=0, leave=True):
    _, _, u0_current, _ = numerov(egs, h, current, x_current=x_current, dx_current=dx_current, direction=-1)
    
    print("egs: ", egs, "u_0: ", u0_current)
    
    if u0_current * u0_last < 0:
        print("guess: ", egs)
        
    u0_last = u0_current
# Out:
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 201994.82it/s]
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 202620.65it/s]
#   2%|█                                           | 1/40 [00:04<03:12,  4.94s/it]
# egs:  -0.7 u_0:  3.253170213235148e-05
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 203931.95it/s]
#   5%|██▏                                         | 2/40 [00:09<03:07,  4.92s/it]
# egs:  -0.6641025641025641 u_0:  3.253170213235148e-05
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 203657.52it/s]
#   8%|███▎                                        | 3/40 [00:14<03:02,  4.92s/it]
# egs:  -0.6282051282051282 u_0:  3.253170213235148e-05
# 100%|███████████████████████████████| 999999/999999 [00:04<00:00, 203190.86it/s]
#  10%|████▍                                       | 4/40 [00:19<02:57,  4.92s/it]
# egs:  -0.5923076923076923 u_0:  3.253170213235148e-05
#  71%|██████████████████████▏        | 714298/999999 [00:03<00:01, 203203.94it/s]
#  10%|████▍                                       | 4/40 [00:23<03:28,  5.80s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2065519/1287106670.py in <module>
#       1 _, _, u0_last, _ = numerov(-4, h, current, x_current=x_current, dx_current=dx_current, direction=-1)
#       2 for egs in tqdm(E_guess, position=0, leave=True):
# ----> 3     _, _, u0_current, _ = numerov(egs, h, current, x_current=x_current, dx_current=dx_current, direction=-1)
#       4
#       5     print("egs: ", egs, "u_0: ", u0_current)
#
# /tmp/ipykernel_2065519/1516682408.py in numerov(E, h, current, x_current, dx_current, direction)
#      20     for i in tqdm(range(n_steps), position=0, leave=True):
#      21
# ---> 22         x_next = xh(current, h*direction, x_current, dx_current, E=E)
#      23
#      24         x_next_leap_frog = xh(current, 0.75*h*direction, x_current, dx_current, E=E)
#
# /tmp/ipykernel_2065519/2826706718.py in xh(current, h, x_current, dx_current, E)
#       1 def xh(current, h, x_current, dx_current, E=-0.5):
# ----> 2     return numerator(current, h, x_current, dx_current, E=-0.5) / denominator(current, h, x_current, dx_current, E=-0.5)
#
# /tmp/ipykernel_2065519/358644182.py in numerator(current, h, x_current, dx_current, E)
#       1 def numerator(current, h, x_current, dx_current, E=-0.5):
# ----> 2     return xh_aux(current, h, E=-0.5) * w_aux(current, -h, E=-0.5) * x_current + 2*h*dx_current*dx_aux(current, -h, E=-0.5)
#
# KeyboardInterrupt:
